# %%
import nltk

# %%
from nltk.corpus import stopwords
stop=stopwords.words('english')
stop
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
Sentence=('''The G-Wagen is @# cha!racterised by its*&  boxy styling and body-on-frame construction. It uses three fully locking differentials, one of the few passenger car vehicles to have such a feature.!''')

from nltk.corpus import stopwords
stop=stopwords.words('english')
from nltk.tokenize import word_tokenize
tok=word_tokenize(Sentence)
rem_token= [i.lower() for i in tok if i.lower() not in stop]
rem_token
# Out:
# ['g-wagen',
#  '@',
#  '#',
#  'cha',
#  '!',
#  'racterised',
#  '*',
#  '&',
#  'boxy',
#  'styling',
#  'body-on-frame',
#  'construction',
#  '.',
#  'uses',
#  'three',
#  'fully',
#  'locking',
#  'differentials',
#  ',',
#  'one',
#  'passenger',
#  'car',
#  'vehicles',
#  'feature',
#  '.',
#  '!']

# %%
import re
str1=re.sub('[^a-zA-z0-9]',' ',' '.join(rem_token))
str1
# Out:
# 'g wagen     cha   racterised     boxy styling body on frame construction   uses three fully locking differentials   one passenger car vehicles feature    '
